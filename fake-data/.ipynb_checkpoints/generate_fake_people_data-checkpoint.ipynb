# %%
# !pip install Faker

# %%
from faker import Faker
fake = Faker(['es_MX'])

# %%
fake.name()
# Out:
# 'Rosalia Yuridia Villaseñor Corrales'

# %%
import pandas as pd

df = pd.DataFrame([fake.profile() for _ in range(1000)])
df
# Out:
#                              job                             company  \
# 0    Information systems manager                Limón y Galindo S.C.
# 1                  Social worker       Club Nieves, Orosco y Casárez
# 2           Maintenance engineer     Barreto y Brito S. R.L. de C.V.
# 3               Surveyor, mining                     Salgado e Hijos
# 4            Immigration officer    Proyectos Botello, Mota y Tejada
# ..                           ...                                 ...
# 995                       Dancer  Corporacin Menéndez, Núñez y Limón
# 996        Clinical psychologist       Laboratorios Ocasio y Barrios
# 997            Buyer, industrial         Carrasco, Riojas y Zambrano
# 998               Futures trader  Grupo Miramontes, Armenta y Dávila
# 999          Art gallery manager                 Niño-Caballero A.C.
#
#              ssn                                          residence  \
# 0    74484683557  Andador Japón 700 Edif. 745 , Depto. 938\nSan ...
# ...

# %%
df.to_csv('people_for_marie.csv', encoding='latin1')
